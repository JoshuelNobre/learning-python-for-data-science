# %% [markdown]
# ## Python possui 2 tipos de números principais
# #int = números inteiros positivos ou negativos
# #float = números quebrados

# %%
type(7) #descubro o tipo de número
# Out:
# int

# %%
type(7.5)
# Out:
# float

# %%
int(8.5) #converte para int
# Out:
# 8

# %%
float(9) #converte para float
# Out:
# 9.0

# %%
7+8 #soma
# Out:
# 15

# %%
5-3 #subtração
# Out:
# 2

# %%
2*4 #multiplicação
# Out:
# 8

# %%
6/2 #divisão sempre retorna float
# Out:
# 3.0

# %%
6//2 #com duas barras retorna inteiro
# Out:
# 3

# %%
10%3 #módulo/resto da divisão
# Out:
# 1

# %%
5**2 #potência
# Out:
# 25

# %%
a = 'Eu sou uma string'

# %%
type(a)
# Out:
# str

# %%
abs(-5.3) #retorna valor absoluto
# Out:
# 5.3

# %%
round(5.656,2) #arredonda e o "2" representa quantas casas terei depois da vírgula.
# Out:
# 5.66

# %%
round(5.656)
# Out:
# 6

# %%
round(5.5684,1)
# Out:
# 5.6
