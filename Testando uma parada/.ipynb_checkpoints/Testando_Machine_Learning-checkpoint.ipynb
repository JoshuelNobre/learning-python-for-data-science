# %% [markdown]
# # Learning ML

# %%
import pandas as pd
arquivo = pd.read_csv('wine_dataset.csv')

# %%
arquivo
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  style
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]

# %%
arquivo['style'] = arquivo['style'].replace('red',0) #o Valor red na coluna style recebe 0

# %%
arquivo['style'] = arquivo['style'].replace('white',1) # o Valor white na coluna style recebe 1

# %%
arquivo['style']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6492    1
# 6493    1
# 6494    1
# 6495    1
# 6496    1
# Name: style, Length: 6497, dtype: int64

# %%
#Separando as variáveis entre preditoras e variável alvo
y = arquivo['style']
x = arquivo.drop('style', axis = 1) # x recebe tudo menos a coluna style, (axis = 1 é coluna)

# %%
x
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 6492     11.2        6
# 6493      9.6        5
# 6494      9.4        6
# 6495     12.8        7
# 6496     11.8        6
#
# [6497 rows x 12 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6492    1
# 6493    1
# 6494    1
# 6495    1
# 6496    1
# Name: style, Length: 6497, dtype: int64

# %%
from sklearn.model_selection import train_test_split #Importando função do sklearn chamada train_test_split

#criando conjunto de dados de treino e teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3) #Quero que 30% dos dados sejam para teste

# %%
from sklearn.ensemble import ExtraTreesClassifier
#Criação de modelo
modelo = ExtraTreesClassifier()
modelo.fit(x_treino,y_treino) #fit é treinar
 
#Imprimindo resultado
resultado = modelo.score(x_teste,y_teste)
print('Acurácia: ', resultado)
# Out:
# Acurácia:  0.9969230769230769

# %%
y_teste[400:404] #Amostra 400 a 4004
# Out:
# 1303    0
# 2401    1
# 920     0
# 509     0
# Name: style, dtype: int64

# %%
x_teste[400:404]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1303            8.0              0.28         0.44             1.8      0.081
# 2401            6.8              0.39         0.35            11.6      0.044
# 920             9.6              0.41         0.37             2.3      0.091
# 509            13.3              0.29         0.75             2.8      0.084
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 1303                 28.0                  68.0  0.99501  3.36       0.66
# 2401                 57.0                 220.0  0.99775  3.07       0.53
# 920                  10.0                  23.0  0.99786  3.24       0.56
# 509                  23.0                  43.0  0.99860  3.04       0.68
#
#       alcohol  quality
# 1303     11.2        5
# 2401      9.3        5
# 920      10.5        5
# 509      11.4        7

# %%
previsoes = modelo.predict(x_teste[400:404])

# %%
previsoes
# Out:
# array([0, 1, 0, 0], dtype=int64)
