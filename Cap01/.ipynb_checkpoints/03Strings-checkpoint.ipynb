# %% [markdown]
# ## Strings

# %%
texto= "Python é legal"

# %%
texto[0] #Indexação em python começa em 0
# Out:
# 'P'

# %%
texto[1]
# Out:
# 'y'

# %%
texto[7]
# Out:
# 'é'

# %%
'Olá'
# Out:
# 'Olá'

# %%
"Testando strings'"
# Out:
# "Testando strings'"

# %%
print("Testando strings'")
# Out:
# Testando strings'

# %%
print("Testando \nstrings \nno \nJupyter notebook")
# Out:
# Testando
# strings
# no
# Jupyter notebook

# %%
print("\n") #enter

# %%
xuel="Jogador de lol"

# %%
xuel[2:]# O dois pontos faz a leitura de tudo até o ponto designado
# Out:
# 'gador de lol'

# %%
xuel[2:6]
# Out:
# 'gado'

# %%
xuel[:6]
# Out:
# 'Jogado'

# %%
xuel[:]
# Out:
# 'Jogador de lol'

# %%
xuel[-1]
# Out:
# 'l'

# %%
xuel[-5]
# Out:
# 'e'

# %%
xuel[-5:]
# Out:
# 'e lol'

# %%
xuel[:-5]
# Out:
# 'Jogador d'

# %%
xuel
# Out:
# 'Jogador de lol'

# %%
xuel[::1]
# Out:
# 'Jogador de lol'

# %%
xuel[::2]
# Out:
# 'Jgdrd o'

# %%
xuel[::-1]
# Out:
# 'lol ed rodagoJ'

# %%
xuel[::-2]
# Out:
# 'lle oao'

# %%
xuel + " e CSGO" #Concatenação
# Out:
# 'Jogador de lol e CSGO e CSGO'

# %%
xuel= xuel+ " e CSGO"

# %%
xuel
# Out:
# 'Jogador de lol e CSGO'

# %%
letra= "U" #Podemos usar a multiplicação

# %%
letra*4
# Out:
# 'UUUU'

# %%
xuel.upper() #String + ponto, TAB para ver funções built-in
# Out:
# 'JOGADOR DE LOL E CSGO'

# %%
xuel.split() #Divide por espaços
# Out:
# ['Jogador', 'de', 'lol', 'e', 'CSGO']

# %%
xuel.split("r") #Divide em certa letra
# Out:
# ['Jogado', ' de lol e CSGO']

# %%
abc="oi, eu sou goku"

# %%
abc.capitalize()#Primeira letra maiúscula
# Out:
# 'Oi, eu sou goku'

# %%
abc.count("o") #Conta quantos "o" tem na string
# Out:
# 3

# %%
abc.find("e") #Encontrar a letra "e" na string
# Out:
# 4

# %%
abc.islower() #Minha string é minuscula?
# Out:
# True

# %%
abc.isspace() #Minha string é um espaço?
# Out:
# False

# %%
abc.endswith("u") #Minha string terrmina em "U" ?
# Out:
# True

# %%
"Python"=="Java" #Comparando strings
# Out:
# False

# %%
cobra="Python" #Definindo string para teste

# %%
"Python"==cobra
# Out:
# True

# %%
"Python"=="cobra"
# Out:
# False
